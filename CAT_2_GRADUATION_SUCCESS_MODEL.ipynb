# %% [markdown]
# <a href="https://colab.research.google.com/github/rono1579/CAT-2/blob/main/CAT_2_GRADUATION_SUCCESS_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA SCIENCE CAT 2;**
#
# BCS-05-0130/2022

# %%
import pandas as pd

YUSUF = pd.read_csv('/content/graduation_dataset.csv')

YUSUF.head(5)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Previous qualification  Mother's occupation  Father's occupation  \
# 0                       1                    6                   10
# 1                       1                    4                    4
# 2                       1                   10                   10
# 3                       1                    6                    4
# 4                       1                   10                   10
#
#    Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  \
# 0                        1       1                   0                 20
# ...

# %%
YUSUF.shape
# Out:
# (99, 14)

# %%
YUSUF.describe()
# Out:
#        Marital status  Application mode  Application order     Course  \
# count       99.000000         99.000000          99.000000  99.000000
# mean         1.131313          6.727273           1.919192   9.969697
# std          0.487527          5.170201           1.468560   4.454886
# min          1.000000          1.000000           1.000000   1.000000
# 25%          1.000000          1.000000           1.000000   7.000000
# 50%          1.000000          8.000000           1.000000  11.000000
# 75%          1.000000         12.000000           2.500000  12.000000
# max          4.000000         17.000000           6.000000  17.000000
#
#        Previous qualification  Mother's occupation  Father's occupation  \
# count               99.000000            99.000000            99.000000
# mean                 2.373737             7.151515             7.464646
# std                  3.824160             2.844126             3.124339
# ...

# %%
YUSUF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Marital status           99 non-null     int64
#  1   Application mode         99 non-null     int64
#  2   Application order        99 non-null     int64
#  3   Course                   99 non-null     int64
#  4   Previous qualification   99 non-null     int64
#  5   Mother's occupation      99 non-null     int64
#  6   Father's occupation      99 non-null     int64
#  7   Tuition fees up to date  99 non-null     int64
#  8   Gender                   99 non-null     int64
#  9   Scholarship holder       99 non-null     int64
#  10  Age at enrollment        99 non-null     int64
#  11  Unemployment rate        99 non-null     float64
#  12  GDP                      99 non-null     float64
#  13  Target                   99 non-null     object
# ...

# %%
Y = YUSUF.drop('Target', axis=1)

# %%
Y
# Out:
#     Marital status  Application mode  Application order  Course  \
# 0                1                 8                  5       2
# 1                1                 6                  1      11
# 2                1                 1                  5       5
# 3                1                 8                  2      15
# 4                2                12                  1       3
# ..             ...               ...                ...     ...
# 94               2                12                  1       3
# 95               1                 6                  1       7
# 96               1                 1                  5      15
# 97               1                 1                  5      12
# 98               1                 1                  1       6
#
#     Previous qualification  Mother's occupation  Father's occupation  \
# 0                        1                    6                   10
# ...

# %%
X = YUSUF['Target']
X.head()
# Out:
# 0     Dropout
# 1    Graduate
# 2     Dropout
# 3    Graduate
# 4    Graduate
# Name: Target, dtype: object

# %%
from sklearn.model_selection import train_test_split

Y_train, Y_test, X_train, X_test = train_test_split(Y, X, test_size = 0.2, random_state = 42)

# %%
Y_train
# Out:
#     Marital status  Application mode  Application order  Course  \
# 49               1                 1                  1      10
# 70               1                 8                  1       9
# 68               1                 1                  3       9
# 15               1                 1                  1      15
# 39               1                15                  1       8
# ..             ...               ...                ...     ...
# 60               1                 1                  2      12
# 71               1                 8                  1      12
# 14               1                 1                  1       6
# 92               1                 6                  1       8
# 51               1                 1                  1      12
#
#     Previous qualification  Mother's occupation  Father's occupation  \
# 49                       1                   10                   10
# ...

# %%
Y_test
# Out:
#     Marital status  Application mode  Application order  Course  \
# 62               1                 8                  3       2
# 40               1                 1                  5      15
# 95               1                 6                  1       7
# 18               1                 1                  1       8
# 97               1                 1                  5      12
# 84               2                12                  1       3
# 64               1                14                  1       5
# 42               1                 1                  6      12
# 10               1                 1                  1      14
# 0                1                 8                  5       2
# 31               1                16                  1       5
# 76               1                 9                  4      11
# 47               1                 8                  6      12
# 26               1                 8                  2      10
# ...

# %%
X_train
# Out:
# 49    Graduate
# 70    Enrolled
# 68     Dropout
# 15     Dropout
# 39     Dropout
#         ...
# 60    Graduate
# 71    Graduate
# 14    Graduate
# 92     Dropout
# 51    Enrolled
# Name: Target, Length: 79, dtype: object

# %%
X_test
# Out:
# 62    Enrolled
# 40     Dropout
# 95    Enrolled
# 18    Graduate
# 97    Graduate
# 84    Graduate
# 64    Enrolled
# 42    Graduate
# 10    Graduate
# 0      Dropout
# 31    Graduate
# 76     Dropout
# 47    Graduate
# 26    Graduate
# 44     Dropout
# 4     Graduate
# 22    Graduate
# 12     Dropout
# 88    Enrolled
# 73     Dropout
# Name: Target, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

Y_train = sc.fit_transform(Y_train)
Y_test= sc.transform(Y_test)

Y_test
# Out:
# array([[-0.26710361,  0.23209423,  1.16885804, -1.86202463, -0.41102059,
#         -0.80102684,  0.22882876,  0.35856858,  1.24434203,  1.77704663,
#         -0.52749756, -0.33967953,  0.6893893 ],
#        [-0.26710361, -1.11893851,  2.89483533,  1.11200227, -0.41102059,
#         -1.54115689, -1.57891843,  0.35856858, -0.80363756, -0.56273143,
#         -0.65454727,  0.33832442, -0.81469256],
#        [-0.26710361, -0.15391512, -0.55711925, -0.71816813, -0.41102059,
#          1.04929831, -1.57891843,  0.35856858,  1.24434203, -0.56273143,
#         -0.52749756,  0.76653745,  0.27401786],
#        [-0.26710361, -1.11893851, -0.55711925, -0.48939683, -0.41102059,
#         -1.17109187, -0.49427012,  0.35856858, -0.80363756, -0.56273143,
#         -0.40044784, -0.33967953,  0.6893893 ],
#        [-0.26710361, -1.11893851,  2.89483533,  0.42568837, -0.41102059,
#          0.30916825,  0.22882876,  0.35856858, -0.80363756,  1.77704663,
#         -0.65454727,  0.23127117,  0.71125095],
# ...

# %%
Y_train
# Out:
# array([[-0.26710361, -1.11893851, -0.55711925, ..., -0.52749756,
#          0.33832442, -0.81469256],
#        [-0.26710361,  0.23209423, -0.55711925, ..., -0.65454727,
#         -1.48158093,  0.0685183 ],
#        [-0.26710361, -1.11893851,  1.16885804, ..., -0.52749756,
#          1.58727908, -0.47365074],
#        ...,
#        [-0.26710361, -1.11893851, -0.55711925, ..., -0.65454727,
#         -0.33967953,  0.6893893 ],
#        [-0.26710361, -0.15391512, -0.55711925, ...,  0.36185046,
#         -1.01768348,  1.46329188],
#        [-0.26710361, -1.11893851, -0.55711925, ..., -0.52749756,
#         -0.83926139, -1.43556355]])

# %%
import numpy as np

value_counts = X.value_counts()
value_counts
# Out:
# Graduate    49
# Dropout     28
# Enrolled    22
# Name: Target, dtype: int64

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
X_train
# Out:
# array(['Graduate', 'Enrolled', 'Dropout', 'Dropout', 'Dropout',
#        'Graduate', 'Dropout', 'Dropout', 'Graduate', 'Dropout',
#        'Graduate', 'Enrolled', 'Graduate', 'Enrolled', 'Graduate',
#        'Enrolled', 'Enrolled', 'Dropout', 'Enrolled', 'Dropout',
#        'Graduate', 'Dropout', 'Graduate', 'Enrolled', 'Enrolled',
#        'Dropout', 'Enrolled', 'Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Dropout', 'Graduate', 'Dropout',
#        'Enrolled', 'Dropout', 'Dropout', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Dropout',
#        'Dropout', 'Enrolled', 'Dropout', 'Enrolled', 'Enrolled',
#        'Enrolled', 'Dropout', 'Enrolled', 'Graduate', 'Enrolled',
#        'Enrolled', 'Dropout', 'Graduate', 'Graduate', 'Dropout',
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
gb = GradientBoostingClassifier()
gb.fit(Y_train, X_train)
X_prediction = gb.predict(Y_test)
print(accuracy_score(X_test, X_prediction))
# Out:
# 0.5

# %%
Models_Percentage = pd.DataFrame({'Models':['GradientBoostingClassifier'], 'AccuracyScore':[accuracy_score(X_test, X_prediction)
                                                                                            ]})

# %%
Models_Percentage
# Out:
#                        Models  AccuracyScore
# 0  GradientBoostingClassifier            0.5

# %%
Y= YUSUF.drop('Target', axis=1)
Y
# Out:
#     Marital status  Application mode  Application order  Course  \
# 0                1                 8                  5       2
# 1                1                 6                  1      11
# 2                1                 1                  5       5
# 3                1                 8                  2      15
# 4                2                12                  1       3
# ..             ...               ...                ...     ...
# 94               2                12                  1       3
# 95               1                 6                  1       7
# 96               1                 1                  5      15
# 97               1                 1                  5      12
# 98               1                 1                  1       6
#
#     Previous qualification  Mother's occupation  Father's occupation  \
# 0                        1                    6                   10
# ...

# %%
X = YUSUF['Target']
X
# Out:
# 0      Dropout
# 1     Graduate
# 2      Dropout
# 3     Graduate
# 4     Graduate
#         ...
# 94    Graduate
# 95    Enrolled
# 96    Graduate
# 97    Graduate
# 98    Enrolled
# Name: Target, Length: 99, dtype: object

# %%
Y = sc.fit_transform(Y)

Y
# Out:
# array([[-0.27071586,  0.24741866,  2.10851883, ..., -0.39310712,
#         -0.38838924,  0.69948389],
#        [-0.27071586, -0.14138209, -0.62909906, ..., -0.52458551,
#          0.77677848,  0.2709076 ],
#        [-0.27071586, -1.11338395,  2.10851883, ..., -0.52458551,
#         -0.38838924,  0.69948389],
#        ...,
#        [-0.27071586, -1.11338395,  2.10851883, ..., -0.6560639 ,
#         -1.10252429,  1.49798918],
#        [-0.27071586, -1.11338395,  2.10851883, ..., -0.6560639 ,
#          0.21298765,  0.72204054],
#        [-0.27071586, -1.11338395, -0.62909906, ..., -0.52458551,
#          0.32574581, -0.8524134 ]])

# %%
rf = GradientBoostingClassifier()
rf.fit(Y,X)
# Out:
# GradientBoostingClassifier()

# %%
import joblib

joblib.dump(rf, 'Graduation_Success_Model')
# Out:
# ['Graduation_Success_Model']
